# %% [markdown]
# TEST Jupyter notebook
#
# There is a standwaxss with typo

# %%
# function with style problem
def func():
    print("Hello, World!")
    return 42

if __name__ == "__main__":
    func()

def test():
    a= 1
    b= 2
    assert a+b  ==3
    l = [0,1,2,3,4,5]
    g =l[1: 4]
